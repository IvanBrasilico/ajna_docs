# %%
import csv
import pandas as pd
import os
CARGA_BASE = '/home/ivan/pybr/AJNA_MOD/sentinela/CSV/1/2018/1219/'
files =  sorted(os.listdir(CARGA_BASE))

# %%
dfs = {}
for r in range(len(files)):
    print(files[r])
    with open(os.path.join(CARGA_BASE, files[r]), 'r',
              encoding='latin1', newline='') as arq:
        reader = csv.reader(arq)
        lista = [linha for linha in reader]
    width = len(lista[0])
    for ind, linha in enumerate(lista):
        width_linha = len(linha)
        if width_linha!=width:
            print('Erro: ', 'Header ', width, 'Linha ', width2)
            print(lista[0])
            print(lista[ind-1])
            print(linha)
            for header, certo, errado in zip(lista[0], lista[ind-1], lista[ind]):
                print(header, 'Certo', certo[:10], 'Errado', errado[:10])
        if width_linha > width:
            for index, col in enumerate(linha):
                if isinstance(col, str) and not col:
                    print('****Primeira coluna nula:', index)
                    linha.pop(index)
                    break

        
    column_lenght = len(lista[1])
    header_lenght = len(lista[0])
    lenght = header_lenght
    if column_lenght < header_lenght:
        lenght = column_lenght
    print('Headers', header_lenght, 'Columns', column_lenght, 'Final', lenght)
    df = pd.DataFrame(lista[1:], columns=lista[0])
    dfs[files[r]] = df
# Out:
# AtracDesatracEscala.csv
# Headers 9 Columns 9 Final 9
# CargaSolta.csv
# Erro:  Header  66 Linha  66
# ['Conhecimento', 'Item', 'TipoEmbalagem', 'Quantidade', 'Marca', 'Contramarca', 'TipoBloqueio1', 'MotivoBloqueio1', 'JustificativaBloqueio1', 'CPFResponsavelBloqueio1', 'NomeResponsavelBloqueio1', 'DataBloqueio1', 'HoraBloqueio1', 'DesbloqueadoPeloTransportador1', 'CPFResponsavelDesbloqueio1', 'NomeResponsavelDesbloqueio1', 'DataDesbloqueio1', 'HoraDesbloqueio1', 'JustificativaDesbloqueio1', 'TipoBloqueio2', 'MotivoBloqueio2', 'JustificativaBloqueio2', 'CPFResponsavelBloqueio2', 'NomeResponsavelBloqueio2', 'DataBloqueio2', 'HoraBloqueio2', 'DesbloqueadoPeloTransportador2', 'CPFResponsavelDesbloqueio2', 'NomeResponsavelDesbloqueio2', 'DataDesbloqueio2', 'HoraDesbloqueio2', 'JustificativaDesbloqueio2', 'TipoBloqueio3', 'MotivoBloqueio3', 'JustificativaBloqueio3', 'CPFResponsavelBloqueio3', 'NomeResponsavelBloqueio3', 'DataBloqueio3', 'HoraBloqueio3', 'DesbloqueadoPeloTransportador3', 'CPFResponsavelDesbloqueio3', 'NomeResponsavelDesbloqueio3', 'DataDesbloqueio3', 'HoraDesbloqueio3', 'JustificativaDesbloqueio3', 'TipoBloqueio4', 'MotivoBloqueio4', 'JustificativaBloqueio4', 'CPFResponsavelBloqueio4', 'NomeResponsavelBloqueio4', 'DataBloqueio4', 'HoraBloqueio4', 'DesbloqueadoPeloTransportador4', 'CPFResponsavelDesbloqueio4', 'NomeResponsavelDesbloqueio4', 'DataDesbloqueio4', 'HoraDesbloqueio4', 'JustificativaDesbloqueio4', 'QuantidadeBloqueiosAtivos', 'QuantidadeBloqueiosInativos', 'IndicadorHistoricoBloqueio', 'IndicadorHistoricoPedidoRetificacao', 'PesoBrutoItem(Kg)', 'VolumeItem(m3)', 'CodigoMercadoriaPerigosa', 'CodigoClasseMercadoriaPerigosa']
# ['151505214428584', '0001', 'PALLETS', '0000003', 'SCHAEFFLER BRASIL LTD', 'SCHAEFFLER BRASIL LTD', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '00', '00', '', '', '000001086,000', '0000000001,086', '', '']
# ['151505214483410', '0001', 'PALLETS', '0000003', 'SCHAEFFLER BRASIL LTD. ', 'AVENIDA ALEXANDRE MACKENZIE, 14', '1.ARMZ 1 PARTE C - JAGUARE CEP 05322-000 - SAO PAULO, S', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '00', '00', '', '', '000001086,000', '0000000001,086', '', '']
# Conhecimento Certo 1515052144 Errado 1515052144
# Item Certo 0001 Errado 0001
# TipoEmbalagem Certo PALLETS Errado PALLETS
# Quantidade Certo 0000003 Errado 0000003
# Marca Certo SCHAEFFLER Errado SCHAEFFLER
# Contramarca Certo SCHAEFFLER Errado AVENIDA AL
# TipoBloqueio1 Certo  Errado 1.ARMZ 1 P
# MotivoBloqueio1 Certo  Errado
# JustificativaBloqueio1 Certo  Errado
# CPFResponsavelBloqueio1 Certo  Errado
# NomeResponsavelBloqueio1 Certo  Errado
# DataBloqueio1 Certo  Errado
# HoraBloqueio1 Certo  Errado
# DesbloqueadoPeloTransportador1 Certo  Errado
# CPFResponsavelDesbloqueio1 Certo  Errado
# NomeResponsavelDesbloqueio1 Certo  Errado
# DataDesbloqueio1 Certo  Errado
# HoraDesbloqueio1 Certo  Errado
# JustificativaDesbloqueio1 Certo  Errado
# TipoBloqueio2 Certo  Errado
# MotivoBloqueio2 Certo  Errado
# JustificativaBloqueio2 Certo  Errado
# CPFResponsavelBloqueio2 Certo  Errado
# NomeResponsavelBloqueio2 Certo  Errado
# DataBloqueio2 Certo  Errado
# HoraBloqueio2 Certo  Errado
# DesbloqueadoPeloTransportador2 Certo  Errado
# CPFResponsavelDesbloqueio2 Certo  Errado
# NomeResponsavelDesbloqueio2 Certo  Errado
# DataDesbloqueio2 Certo  Errado
# HoraDesbloqueio2 Certo  Errado
# JustificativaDesbloqueio2 Certo  Errado
# TipoBloqueio3 Certo  Errado
# MotivoBloqueio3 Certo  Errado
# JustificativaBloqueio3 Certo  Errado
# CPFResponsavelBloqueio3 Certo  Errado
# NomeResponsavelBloqueio3 Certo  Errado
# DataBloqueio3 Certo  Errado
# HoraBloqueio3 Certo  Errado
# DesbloqueadoPeloTransportador3 Certo  Errado
# CPFResponsavelDesbloqueio3 Certo  Errado
# NomeResponsavelDesbloqueio3 Certo  Errado
# DataDesbloqueio3 Certo  Errado
# HoraDesbloqueio3 Certo  Errado
# JustificativaDesbloqueio3 Certo  Errado
# TipoBloqueio4 Certo  Errado
# MotivoBloqueio4 Certo  Errado
# JustificativaBloqueio4 Certo  Errado
# CPFResponsavelBloqueio4 Certo  Errado
# NomeResponsavelBloqueio4 Certo  Errado
# DataBloqueio4 Certo  Errado
# HoraBloqueio4 Certo  Errado
# DesbloqueadoPeloTransportador4 Certo  Errado
# CPFResponsavelDesbloqueio4 Certo  Errado
# NomeResponsavelDesbloqueio4 Certo  Errado
# DataDesbloqueio4 Certo  Errado
# HoraDesbloqueio4 Certo  Errado
# JustificativaDesbloqueio4 Certo  Errado
# QuantidadeBloqueiosAtivos Certo 00 Errado
# QuantidadeBloqueiosInativos Certo 00 Errado 00
# IndicadorHistoricoBloqueio Certo  Errado 00
# IndicadorHistoricoPedidoRetificacao Certo  Errado
# PesoBrutoItem(Kg) Certo 000001086, Errado
# VolumeItem(m3) Certo 0000000001 Errado 000001086,
# CodigoMercadoriaPerigosa Certo  Errado 0000000001
# CodigoClasseMercadoriaPerigosa Certo  Errado
# ****Primeira coluna nula: 7
# Headers 66 Columns 66 Final 66
# Conhecimento.csv
# Headers 117 Columns 117 Final 117
# Container.csv
# Headers 71 Columns 71 Final 71
# ContainerVazio.csv
# Headers 5 Columns 5 Final 5
# Escala.csv
# Headers 50 Columns 50 Final 50
# EscalaManifesto.csv
# Headers 2 Columns 2 Final 2
# Granel.csv
# Headers 64 Columns 64 Final 64
# Manifesto.csv
# Headers 65 Columns 65 Final 65
# ManifestoConhecimento.csv
# Headers 6 Columns 6 Final 6
# NCM.csv
# Headers 4 Columns 4 Final 4
# Parametros.csv
# Headers 27 Columns 27 Final 27
# Transbordo.csv
# Headers 3 Columns 3 Final 3
# Veiculo.csv
# Headers 62 Columns 62 Final 62

# %%
r=0
print(files[r])
dfs[files[r]].head(2)
# Out:
# AtracDesatracEscala.csv
#         Escala CodigoTerminal  \
# 0  15000365317       BRSSZ009
# 1  15000386934       BRSSZ016
#
#                                         NomeTerminal  Situacao DataAtracacao  \
# 0  EMBRAPORT EMPRESA BRASILEIRA DE TERMINAIS PORT...  ATRACADA    01/10/2015
# 1                                      SANTOS BRASIL  ATRACADA    01/10/2015
#
#   HoraAtracacao DataDesatracacao HoraDesatracacao  LocalAtracacao
# 0      17:46:00       02/10/2015         14:09:00     EMBRAPORT 2
# 1      09:15:00       02/10/2015         15:14:00  TECON PONTO 01

# %%
r=1
print(files[r])
dfs[files[r]].head(2)
# Out:
# CargaSolta.csv
#       Conhecimento  Item TipoEmbalagem Quantidade                 Marca  \
# 0  151505205125698  0001       PALLETS    0000012  FISCHERBRASILINDYCOM
# 1  151505205487336  0001       PALLETS    0000012        FISCHER BRASIL
#
#             Contramarca TipoBloqueio1 MotivoBloqueio1 JustificativaBloqueio1  \
# 0  FISCHERBRASILINDYCOM
# 1        FISCHER BRASIL
#
#   CPFResponsavelBloqueio1              ...               HoraDesbloqueio4  \
# 0                                      ...
# 1                                      ...
#
#   JustificativaDesbloqueio4 QuantidadeBloqueiosAtivos  \
# 0                                                  00
# 1                                                  00
#
#   QuantidadeBloqueiosInativos IndicadorHistoricoBloqueio  \
# 0                          00
# 1                          00
#
#   IndicadorHistoricoPedidoRetificacao PesoBrutoItem(Kg)  VolumeItem(m3)  \
# 0                                         000004538,800  0000000016,790
# 1                                         000004538,800  0000000016,790
#
#   CodigoMercadoriaPerigosa CodigoClasseMercadoriaPerigosa
# 0
# 1
#
# [2 rows x 66 columns]

# %%
r=2
print(files[r])
dfs[files[r]].head(2)
# Out:
# Conhecimento.csv
#       Conhecimento QuantidadeBloqueiosAtivos QuantidadeBloqueiosInativos  \
# 0  151505204660875                                                    00
# 1  151505204660956                                                    00
#
#   TipoBloqueio1 MotivoBloqueio1 JustificativaBloqueio1  \
# 0
# 1
#
#   CPFResponsavelBloqueio1 NomeResponsavelBloqueio1 DataBloqueio1  \
# 0
# 1
#
#   HoraBloqueio1             ...               \
# 0                           ...
# 1                           ...
#
#   NomeAgenteNavegacaoDesconsolidador CodigoAgenteNavegacaoDesconsolidador  \
# 0
# 1
#
#   NomeNavioPrimeiroTransporte DataEmissaoBLPrimeiroTransporte  \
# 0                   ALLEGORIA
# 1                   ALLEGORIA
#
#   BLPrimeiroTransporte      ValorFrete     MoedaFrete ModalidadeFrete  \
# 0                       00000000672,00  DOLAR DOS EUA  HOUSE TO HOUSE
# 1                       00000000672,00  DOLAR DOS EUA  HOUSE TO HOUSE
#
#   RecolhimentoFrete IndicadorCargaConteinerizada
# 0           PREPAID                            S
# 1           PREPAID                            S
#
# [2 rows x 117 columns]

# %%
r=3
print(files[r])
dfs[files[r]].head(2)
# Out:
# Container.csv
#       Conhecimento  Item    Container TipoBloqueio1 MotivoBloqueio1  \
# 0  151505204660875  0001  EXFU5501005
# 1  151505204660956  0001  TIFU3501484
#
#   JustificativaBloqueio1 CPFResponsavelBloqueio1 NomeResponsavelBloqueio1  \
# 0
# 1
#
#   DataBloqueio1 HoraBloqueio1              ...                Lacre3  Lacre4  \
# 0                                          ...                324309  324309
# 1                                          ...                905549
#
#                                       Tipo Capacidade TaraContainer  \
# 0         TANK DANGER. LIQU. 4 BAR,20'/8'6         20    004000,000
# 1  TANK NON-DANGER. LIQU. 0.45 BAR,20'/8'6         20    004000,000
#
#    PesoBrutoItem      VolumeItem IndicadorUsoParcial CodigoMercadoriaPerigosa  \
# 0  000022820,000  0000000017,000
# 1  000022730,000  0000000017,000
#
#   CodigoClasseMercadoriaPerigosa
# 0
# 1
#
# [2 rows x 71 columns]

# %%
r=4
print(files[r])
dfs[files[r]].head(2)
# Out:
# ContainerVazio.csv
#        Manifesto    Container            NomeTipo Capacidade(Pés)    Tara(Kg)
# 0  1815502323315  HLXU3607622  OPENTOP(20'/8'6'')              20  002450,000
# 1  1815502323315  HLXU3607659  OPENTOP(20'/8'6'')              20  002450,000

# %%
r=5
print(files[r])
dfs[files[r]].head(2)
# Out:
# Escala.csv
#         Escala NomeEmbarcacao CodigoIMO TipoBloqueio1 MotivoBloqueio1  \
# 0  15000365317      ALLEGORIA   9295945
# 1  15000386934       MAIRA XL   9710232
#
#   JustificativaBloqueio1 CPFResponsavelBloqueio1 NomeResponsavelBloqueio1  \
# 0
# 1
#
#   DataBloqueio1 HoraBloqueio1          ...           HoraDesbloqueio3  \
# 0                                      ...
# 1                                      ...
#
#   JustificativaDesbloqueio3 QuantidadeBloqueiosAtivos  \
# 0
# 1
#
#   IndicadorHistoricoBloqueios                 NomeAgenciaNavegacao  \
# 0                                   ROCHAMAR AGENCIA MARITIMA S.A.
# 1                              COSCO SHIPPING LINES  (BRASIL) S.A.
#
#   CNPJAgenciaNavegacao DataPrevistaAtracacao DataEfetivaAtracacao  \
# 0       11256147000325            27/09/2015           01/10/2015
# 1       02502234000243            01/10/2015           01/10/2015
#
#   DataPrevistaDesatracacao DataUltimaDesatracacao
# 0               28/09/2015             02/10/2015
# 1               02/10/2015             02/10/2015
#
# [2 rows x 50 columns]

# %%
r=6
print(files[r])
dfs[files[r]].head(2)
# Out:
# EscalaManifesto.csv
#         Escala      Manifesto
# 0  15000365317  1815502323315
# 1  15000365317  1515502323332

# %%
r=7
print(files[r])
dfs[files[r]].head(2)
# Out:
# Granel.csv
#       Conhecimento  Item               Tipo Descricao TipoBloqueio1  \
# 0  151505201490901  0001  LIQUIDOS - OUTROS
# 1  151505201578159  0001  LIQUIDOS - OUTROS
#
#   MotivoBloqueio1 JustificativaBloqueio1 CPFResponsavelBloqueio1  \
# 0
# 1
#
#   NomeResponsavelBloqueio1 DataBloqueio1              ...                \
# 0                                                     ...
# 1                                                     ...
#
#   HoraDesbloqueio4 JustificativaDesbloqueio4 QuantidadeBloqueiosAtivos  \
# 0                                                                   00
# 1                                                                   00
#
#   QuantidadeBloqueiosInativos IndicadorHistoricoBloqueio  \
# 0                          00
# 1                          00
#
#   IndicadorHistoricoPedidoRetificacao PesoBrutoItem(Kg)  VolumeItem(m3)  \
# 0                                         005366441,000  0000000000,000
# 1                                         007031030,000  0000000000,000
#
#   CodigoMercadoriaPerigosa CodigoClasseMercadoriaPerigosa
# 0                        8                           1824
# 1                        8                           1824
#
# [2 rows x 64 columns]

# %%
r=8
print(files[r])
dfs[files[r]].head(2)
# Out:
# Manifesto.csv
#        Manifesto                  TipoBloqueio1  \
# 0  1815502323315  IMPEDE REGISTRO DE DI/DSI/DTA
# 1  1515502323332
#
#                              MotivoBloqueio1 JustificativaBloqueio1  \
# 0  VINCULAÇÃO MAN/ESC PÓS PRAZO OU ATRACAÇÃO    BLOQUEIO AUTOMATICO
# 1
#
#   CPFResponsavelBloqueio1 NomeResponsavelBloqueio1 DataBloqueio1  \
# 0                                                     01/10/2015
# 1
#
#   HoraBloqueio1 DesbloqueadoPeloTransportador1 CPFResponsavelDesbloqueio1  \
# 0      17:46:52
# 1
#
#               ...              CodigoTerminalCarregamento3  \
# 0             ...
# 1             ...
#
#   NomeTerminalCarregamento3 CodigoPortoDescarregamento  \
# 0                                                BRSSZ
# 1                                                BRSSZ
#
#   NomePortoDescarregamento CodigoTerminalDescarregamento1  \
# 0                   SANTOS                       BRSSZ009
# 1                   SANTOS                       BRSSZ009
#
#                         NomeTerminalDescarregamento1  \
# 0  EMBRAPORT EMPRESA BRASILEIRA DE TERMINAIS PORT...
# 1  EMBRAPORT EMPRESA BRASILEIRA DE TERMINAIS PORT...
#
#   CodigoTerminalDescarregamento2 NomeTerminalDescarregamento2  \
# 0
# 1
#
#   CodigoTerminalDescarregamento3 NomeTerminalDescarregamento3
# 0
# 1
#
# [2 rows x 65 columns]

# %%
r=9
print(files[r])
dfs[files[r]].head(2)
# Out:
# ManifestoConhecimento.csv
#        Manifesto     Conhecimento CodigoTerminalCarregamento  \
# 0  1515502323332  151505204660875
# 1  1515502323332  151505204660956
#
#   NomeTerminalCarregamento CodigoTerminalDescarregamento  \
# 0             BUENOS AIRES                      BRSSZ009
# 1             BUENOS AIRES                      BRSSZ009
#
#                          NomeTerminalDescarregamento
# 0  EMBRAPORT EMPRESA BRASILEIRA DE TERMINAIS PORT...
# 1  EMBRAPORT EMPRESA BRASILEIRA DE TERMINAIS PORT...

# %%
r=10
print(files[r])
dfs[files[r]].head(2)
# Out:
# NCM.csv
#       Conhecimento  Item   NCM  \
# 0  151505204660875  0001  3907
# 1  151505204660956  0001  3907
#
#                                            Descricao
# 0  POLIACETAIS, OUTROS POLIÉTERES E RESINAS EPÓXI...
# 1  POLIACETAIS, OUTROS POLIÉTERES E RESINAS EPÓXI...

# %%
r=11
print(files[r])
dfs[files[r]].head(2)
# Out:
# Parametros.csv
#        Usuario DataRequisicao HoraRequisicao NomeConsulta CategoriaCarga  \
# 0  08259498740     18/09/2017       18:09:59  Outubro2015      Importada
#
#   PortoAtracacao    Periodo DataInicioConsulta DataFinalConsulta Embarcacao  \
# 0          BRSSZ  Atracação         01/10/2015        31/10/2015
#
#          ...        PortoOrigem PaisDestinoFinal PortoDestinoFinal  \
# 0        ...                                                 BRSSZ
#
#   PaisCarregamento PortoCarregamento CNPJ_CPFEmbarcador PaisDescarregamento  \
# 0
#
#   PortoDescarregamento OperadorLogico BloqueioHistorico
# 0                BRSSZ
#
# [1 rows x 27 columns]

# %%
r=12
print(files[r])
print(len(dfs[files[r]]))
dfs[files[r]].head(5)
# Out:
# Transbordo.csv
# 14541
#       Conhecimento CodigoPorto  NomePorto
# 0  151505202615660       HKHKG  HONG KONG
# 1  151505202615740       HKHKG  HONG KONG
# 2  151505202615821       HKHKG  HONG KONG
# 3  151505202617280       HKHKG  HONG KONG
# 4  151505202616399       HKHKG  HONG KONG

# %%
r=13
print(files[r])
dfs[files[r]].head(2)
# Out:
# Veiculo.csv
#       Conhecimento  Item             Chassi Marca  \
# 0  151505204366845  0001  JMYLYV98WGJA00643  MMCB
# 1  151505204366845  0002  JMYLYV98WGJA00658  MMCB
#
#                                          Contramarca TipoBloqueio1  \
# 0  VEHICLES OF MITSUBISHI PRODUCTION YEAR 2015, M...
# 1  VEHICLES OF MITSUBISHI PRODUCTION YEAR 2015, M...
#
#   MotivoBloqueio1 JustificativaBloqueio1 CPFResponsavelBloqueio1  \
# 0
# 1
#
#   NomeResponsavelBloqueio1        ...        CPFResponsavelDesbloqueio4  \
# 0                                 ...
# 1                                 ...
#
#   NomeResponsavelDesbloqueio4 DataDesbloqueio4 HoraDesbloqueio4  \
# 0
# 1
#
#   JustificativaDesbloqueio4 QuantidadeBloqueiosAtivos  \
# 0                                                  00
# 1                                                  00
#
#   QuantidadeBloqueiosInativos IndicadorHistoricoBloqueio  \
# 0                          00
# 1                          00
#
#   IndicadorHistoricoPedidoRetificacao PesoBrutoItem(Kg)
# 0                                         000002240,000
# 1                                         000002240,000
#
# [2 rows x 62 columns]

# %%
dfs['Conhecimento.csv'][['Conhecimento', 'Tipo']].groupby('Tipo').count()
# Out:
#       Conhecimento
# Tipo
# BL           13750
# HBL          25848
# MBL          14131
# MHBL          4622

# %%
FIXED_WIDTH = '/home/ivan/pybr/AJNA_MOD/sentinela/files/P1/'

# %%
import glob
sch_files = sorted([file for file in glob.glob(FIXED_WIDTH+'*.sch')])
txt_files = sorted([file for file in glob.glob(FIXED_WIDTH+'*.txt')])

# %%
txt_files[7]
# Out:
# '/home/ivan/pybr/AJNA_MOD/sentinela/files/P1/Outubro2015FC082594987E170918H180959M502070.txt'

# %%
sch_files[7]
# Out:
# '/home/ivan/pybr/AJNA_MOD/sentinela/files/P1/sch07.sch'

# %%
ENCODE = 'latin1'
path = FIXED_WIDTH
mask_txt='0.txt'

### Igual csv_handler
sch_name = sch_files[7]
txt_name = glob.glob(os.path.join(
    path, '*' + os.path.basename(sch_name)[3:-4] + mask_txt))[0]
with open(sch_name, encoding=ENCODE,
          newline='') as sch_file, \
        open(txt_name, encoding=ENCODE,
             newline='') as txt_file:
    sch_content = sch_file.readlines()
    reader = csv.reader(txt_file, delimiter='\t')
    txt_content = [linha for linha in reader]

        
print(sch_content)
sch = sch_content
cabecalhos = []
larguras = []
for ind in range(len(sch)):
    if not isinstance(sch[ind], str):
        sch[ind] = str(sch[ind], ENCODE)
    linha = sch[ind]
    position_equal = linha.find('="')
    position_quote = linha.find('" ')
    position_col = linha.find('Col')
    if position_equal != -1 and position_col == 0:
        cabecalhos.append(linha[position_equal + 2:position_quote])
        position_width = linha.find('Width')
        larguras.append(linha[position_width + 6:-2])
print(cabecalhos)
print(larguras)
# Out:
# ['[%CargaSolta]\r\n', 'ColNameHeader=True\r\n', 'Format=TabDelimited\r\n', 'MaxScanRows=0\r\n', 'CharacterSet=ANSI\r\n', 'Index=Conhecimento;Item\r\n', 'Relation1=Conhecimento/Conhecimento/Conhecimento\r\n', 'Col1="Conhecimento" Char Width 15\r\n', 'Col2="Item" Char Width 4\r\n', 'Col3="TipoEmbalagem" Char Width 60\r\n', 'Col4="Quantidade" Integer\r\n', 'Col5="Marca" Char Width 55\r\n', 'Col6="Contramarca" Char Width 55\r\n', 'Col7="TipoBloqueio1" Char Width 40\r\n', 'Col8="MotivoBloqueio1" Char Width 60\r\n', 'Col9="JustificativaBloqueio1" LongChar Width 250\r\n', 'Col10="CPFResponsavelBloqueio1" Char Width 11\r\n', 'Col11="NomeResponsavelBloqueio1" LongChar Width 115\r\n', 'Col12="DataBloqueio1" Date \r\n', 'Col13="HoraBloqueio1" Char Width 8\r\n', 'Col14="DesbloqueadoPeloTransportador1" Char Width 1\r\n', 'Col15="CPFResponsavelDesbloqueio1" Char Width 11\r\n', 'Col16="NomeResponsavelDesbloqueio1" LongChar Width 115\r\n', 'Col17="DataDesbloqueio1" Date\r\n', 'Col18="HoraDesbloqueio1" Char Width 8\r\n', 'Col19="JustificativaDesbloqueio1" LongChar Width 250\r\n', 'Col20="TipoBloqueio2" Char Width 40\r\n', 'Col21="MotivoBloqueio2" Char Width 60\r\n', 'Col22="JustificativaBloqueio2" LongChar Width 250\r\n', 'Col23="CPFResponsavelBloqueio2" Char Width 11\r\n', 'Col24="NomeResponsavelBloqueio2" LongChar Width 115\r\n', 'Col25="DataBloqueio2" Date \r\n', 'Col26="HoraBloqueio2" Char Width 8\r\n', 'Col27="DesbloqueadoPeloTransportador2" Char Width 1\r\n', 'Col28="CPFResponsavelDesbloqueio2" Char Width 11\r\n', 'Col29="NomeResponsavelDesbloqueio2" LongChar Width 115\r\n', 'Col30="DataDesbloqueio2" Date\r\n', 'Col31="HoraDesbloqueio2" Char Width 8\r\n', 'Col32="JustificativaDesbloqueio2" LongChar Width 250\r\n', 'Col33="TipoBloqueio3" Char Width 40\r\n', 'Col34="MotivoBloqueio3" Char Width 60\r\n', 'Col35="JustificativaBloqueio3" LongChar Width 250\r\n', 'Col36="CPFResponsavelBloqueio3" Char Width 11\r\n', 'Col37="NomeResponsavelBloqueio3" LongChar Width 115\r\n', 'Col38="DataBloqueio3" Date \r\n', 'Col39="HoraBloqueio3" Char Width 8\r\n', 'Col40="DesbloqueadoPeloTransportador3" Char Width 1\r\n', 'Col41="CPFResponsavelDesbloqueio3" Char Width 11\r\n', 'Col42="NomeResponsavelDesbloqueio3" LongChar Width 115\r\n', 'Col43="DataDesbloqueio3" Date\r\n', 'Col44="HoraDesbloqueio3" Char Width 8\r\n', 'Col45="JustificativaDesbloqueio3" LongChar Width 250\r\n', 'Col46="TipoBloqueio4" Char Width 40\r\n', 'Col47="MotivoBloqueio4" Char Width 60\r\n', 'Col48="JustificativaBloqueio4" LongChar Width 250\r\n', 'Col49="CPFResponsavelBloqueio4" Char Width 11\r\n', 'Col50="NomeResponsavelBloqueio4" LongChar Width 115\r\n', 'Col51="DataBloqueio4" Date \r\n', 'Col52="HoraBloqueio4" Char Width 8\r\n', 'Col53="DesbloqueadoPeloTransportador4" Char Width 1\r\n', 'Col54="CPFResponsavelDesbloqueio4" Char Width 11\r\n', 'Col55="NomeResponsavelDesbloqueio4" LongChar Width 115\r\n', 'Col56="DataDesbloqueio4" Date\r\n', 'Col57="HoraDesbloqueio4" Char Width 8\r\n', 'Col58="JustificativaDesbloqueio4" LongChar Width 250\r\n', 'Col59="QuantidadeBloqueiosAtivos" Integer\r\n', 'Col60="QuantidadeBloqueiosInativos" Integer\r\n', 'Col61="IndicadorHistoricoBloqueio" Char Width 1\r\n', 'Col62="IndicadorHistoricoPedidoRetificacao" Char Width 1\r\n', 'Col63="PesoBrutoItem(Kg)" Float\r\n', 'Col64="VolumeItem(m3)" Float\r\n', 'Col65="CodigoMercadoriaPerigosa" Char Width 6\r\n', 'Col66="CodigoClasseMercadoriaPerigosa" Char Width 4']
# ['Conhecimento', 'Item', 'TipoEmbalagem', 'Quantidade', 'Marca', 'Contramarca', 'TipoBloqueio1', 'MotivoBloqueio1', 'JustificativaBloqueio1', 'CPFResponsavelBloqueio1', 'NomeResponsavelBloqueio1', 'DataBloqueio1', 'HoraBloqueio1', 'DesbloqueadoPeloTransportador1', 'CPFResponsavelDesbloqueio1', 'NomeResponsavelDesbloqueio1', 'DataDesbloqueio1', 'HoraDesbloqueio1', 'JustificativaDesbloqueio1', 'TipoBloqueio2', 'MotivoBloqueio2', 'JustificativaBloqueio2', 'CPFResponsavelBloqueio2', 'NomeResponsavelBloqueio2', 'DataBloqueio2', 'HoraBloqueio2', 'DesbloqueadoPeloTransportador2', 'CPFResponsavelDesbloqueio2', 'NomeResponsavelDesbloqueio2', 'DataDesbloqueio2', 'HoraDesbloqueio2', 'JustificativaDesbloqueio2', 'TipoBloqueio3', 'MotivoBloqueio3', 'JustificativaBloqueio3', 'CPFResponsavelBloqueio3', 'NomeResponsavelBloqueio3', 'DataBloqueio3', 'HoraBloqueio3', 'DesbloqueadoPeloTransportador3', 'CPFResponsavelDesbloqueio3', 'NomeResponsavelDesbloqueio3', 'DataDesbloqueio3', 'HoraDesbloqueio3', 'JustificativaDesbloqueio3', 'TipoBloqueio4', 'MotivoBloqueio4', 'JustificativaBloqueio4', 'CPFResponsavelBloqueio4', 'NomeResponsavelBloqueio4', 'DataBloqueio4', 'HoraBloqueio4', 'DesbloqueadoPeloTransportador4', 'CPFResponsavelDesbloqueio4', 'NomeResponsavelDesbloqueio4', 'DataDesbloqueio4', 'HoraDesbloqueio4', 'JustificativaDesbloqueio4', 'QuantidadeBloqueiosAtivos', 'QuantidadeBloqueiosInativos', 'IndicadorHistoricoBloqueio', 'IndicadorHistoricoPedidoRetificacao', 'PesoBrutoItem(Kg)', 'VolumeItem(m3)', 'CodigoMercadoriaPerigosa', 'CodigoClasseMercadoriaPerigosa']
# ['15', '4', '60', '"Quantidade" Integer', '55', '55', '40', '60', '250', '11', '115', '="DataBloqueio1" Date ', '8', '1', '11', '115', '="DataDesbloqueio1" Date', '8', '250', '40', '60', '250', '11', '115', '="DataBloqueio2" Date ', '8', '1', '11', '115', '="DataDesbloqueio2" Date', '8', '250', '40', '60', '250', '11', '115', '="DataBloqueio3" Date ', '8', '1', '11', '115', '="DataDesbloqueio3" Date', '8', '250', '40', '60', '250', '11', '115', '="DataBloqueio4" Date ', '8', '1', '11', '115', '="DataDesbloqueio4" Date', '8', '250', '="QuantidadeBloqueiosAtivos" Integer', '="QuantidadeBloqueiosInativos" Integer', '1', '1', '="PesoBrutoItem(Kg)" Float', '="VolumeItem(m3)" Float', '6', '']
